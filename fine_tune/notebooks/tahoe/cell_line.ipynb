# %%
import re
from itertools import combinations
from pathlib import Path
from urllib import request
from urllib.parse import urlparse

import community as community_louvain
import matplotlib.cm as cm
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import networkx as nx
import pandas as pd
import requests
import seaborn as sns
from datasets import Dataset, load_dataset
from matplotlib.colors import to_hex
from matplotlib.patches import Patch
from multiprocess.pool import Pool
from pronto.ontology import Ontology
from tqdm import tqdm

data_path = Path("../../datasets")

# %%
ds = load_dataset(
    "vevotx/Tahoe-100M",
    name="cell_line_metadata",
    split="train",
)
if isinstance(ds, Dataset):
    tahoe_cell_line = pd.DataFrame(ds.to_dict())
else:
    raise TypeError("Expected a `Dataset`, got something else.")


# cellosaurus ID
cellosaurus_ids = tahoe_cell_line["Cell_ID_Cellosaur"].unique().tolist()
# Out:
# Resolving data files:   0%|          | 0/3388 [00:00<?, ?it/s]

# %% [markdown]
# ## 1) CHEMBL API (Deprecated, jump to [Cellosaurus API](#cellosaurus-api))
# Because we are not sure if the tahoe cell line metadata `cell_name` is unique onto the [cell line ontology search](https://www.ebi.ac.uk/ols4/ontologies), let's try mapping the cellosaur ID to an ontology entry. To do so:
# - Let's map the `Cell_ID_Cellosaur` and onto a usable ID on [cell line ontology search](https://www.ebi.ac.uk/ols4/ontologies), like `CLO` or `EFO`.
# - Let's use [CHEMBL web service](https://chembl.gitbook.io/chembl-interface-documentation/web-services/chembl-data-web-services), for [cell lines](https://www.ebi.ac.uk/chembl/api/data/cell_line?cellosaurus_id__in=CVCL_0023,CVCL_1381) that provides such mapping.
# - Alternatively, a [CHEMBL browser](https://www.ebi.ac.uk/chembl/explore/cell_lines/) is provided.

# %%
# Construct the query
cell_ids = ",".join(cellosaurus_ids)
url = f"https://www.ebi.ac.uk/chembl/api/data/cell_line?cellosaurus_id__in={cell_ids}"


# Make the request
def recursive_cell_line_request(url, headers={"Accept": "application/json"}, processed=0, pbar=None):
    if pbar is None:
        total = len(re.findall(r"CVCL_\w+", url))
        pbar = tqdm(total=total, desc="Fetching cell lines from CHEMBL")
    response = requests.get(url, headers=headers)
    response.raise_for_status()
    data = response.json()
    cell_lines_list = data["cell_lines"]
    pbar.update(len(cell_lines_list))
    processed += len(cell_lines_list)
    if data["page_meta"]["next"] is None:
        pbar.close()
        return cell_lines_list

    url_parsed = urlparse(url)
    next_url = f"{url_parsed.scheme}://{url_parsed.netloc}{data['page_meta']['next']}"
    return cell_lines_list + recursive_cell_line_request(
        next_url, headers, processed, pbar
    )

cell_lines_list = recursive_cell_line_request(
    url=url, headers={"Accept": "application/json"}
)

tahoe_chembl_df = pd.DataFrame(cell_lines_list)
tahoe_chembl_df = tahoe_chembl_df.where(tahoe_chembl_df.notna()) # make None to NaN
no_res_cells = [cell for cell in cellosaurus_ids if cell not in tahoe_chembl_df["cellosaurus_id"].to_list()]
print(
    f"There are {len(no_res_cells)}/{len(cellosaurus_ids)} cell lines " \
    "that didn't map to any record in CHEMBL database.\n\n" \
    f"Those are: {no_res_cells}"
)
# Out:
# Fetching cell lines from CHEMBL:  20%|█▉        | 20/102 [00:03<00:14,  5.75it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 27
#      22     next_url = f"{url_parsed.scheme}://{url_parsed.netloc}{data['page_meta']['next']}"
#      23     return cell_lines_list + recursive_cell_line_request(
#      24         next_url, headers, processed, pbar
#      25     )
# ---> 27 cell_lines_list = recursive_cell_line_request(
#      28     url=url, headers={"Accept": "application/json"}
#      29 )
#      31 tahoe_chembl_df = pd.DataFrame(cell_lines_list)
#      32 tahoe_chembl_df = tahoe_chembl_df.where(tahoe_chembl_df.notna()) # make None to NaN
#
# Cell In[3], line 23, in recursive_cell_line_request(url, headers, processed, pbar)
#      21 url_parsed = urlparse(url)
#      22 next_url = f"{url_parsed.scheme}://{url_parsed.netloc}{data['page_meta']['next']}"
# ...

# %%
tahoe_chembl_df
# Out:
#    cell_chembl_id cell_description  cell_id  cell_name cell_source_organism  \
# 0   CHEMBL3307275              T84       39        T84         Homo sapiens
# 1   CHEMBL3307292             SW48       58       SW48         Homo sapiens
# 2   CHEMBL3307326          NCI-N87       97    NCI-N87         Homo sapiens
# 3   CHEMBL3307455             SNU1      252       SNU1         Homo sapiens
# 4   CHEMBL3307458            SNU-5      255      SNU-5         Homo sapiens
# ..            ...              ...      ...        ...                  ...
# 89  CHEMBL4295434           BT-483     5696     BT-483         Homo sapiens
# 90  CHEMBL4296202        NCI-H1373     5772  NCI-H1373         Homo sapiens
# 91  CHEMBL4523536         COLO 201     5890   COLO 201         Homo sapiens
# 92  CHEMBL4523540          Hs 695T     5894    Hs 695T         Homo sapiens
# 93  CHEMBL4630710           TOV21G     5916     TOV21G         Homo sapiens
#
# ...

# %% [markdown]
# ## 2) CELLOSAURUS API
#
# This API is prefered over [CHEMBL API] as cellosaurus ids are guaranteed to map to a database entry which was not the case for CHEMBL.
#
# [Description of the cellosaurus API fields](https://api.cellosaurus.org/api-fields)
# - id: Recommended name. Most frequently the name of the cell line as provided in the original publication.
# - ac: Primary accession. It is the unique identifier of the cell line.
# - sx: Sex of the individual from which the cell line originates.
# - ag: Age at sampling time of the individual from which the cell line was established.
# - ca: Category to which a cell line belongs, one of 14 defined terms. Example: cancer cell line, hybridoma, transformed cell line.
# - dr: Cross-references to external resources: cell lines catalogs, databases, resources listing cell lines as samples or to ontologies.
#   - This is what will contain the `EFO`, `CLO`, `BTO` or `CHEMBL` id.
# - cell-type: Cell type from which the cell line is derived.
# - derived-from-site: Body part (tissue or organ) the cell line is derived from.
# - di: Disease(s) suffered by the individual from which the cell line originated with its NCI Thesaurus or ORDO identifier.
# - hi: Parent cell line from which the cell line originates.
#
# There is many more metadata, but those has been chosen.
# The query link is then construct as follow:
# ```txt
# ### Example
# https://api.cellosaurus.org/cell-line/CVCL_0023?fields=id,ac,sx,ag,ca,dr,cell-type,derived-from-site,di,hi,ch&format=json
# ```
#
# Compared to [Chembl API](#chembl-api-deprecated-jump-to-cellosaurus-api), it is not possible to query ID in batch and we loop over cellosaurus_ids.

# %% [markdown]
# ### a) Retrieve Cell line Metadata

# %%
# Construct the query
url = "https://api.cellosaurus.org/cell-line/{cell_id}?fields=id,ac,sx,ag,ca,dr,cell-type,derived-from-site,di,hi,ch,str&format=json"
headers={"Accept": "application/json"}


metadata_rows = []
str_rows = []
for cell_id in tqdm(cellosaurus_ids):
    response = requests.get(url.format(cell_id=cell_id), headers=headers)
    data = response.json()["Cellosaurus"]["cell-line-list"][0]

    # accession-list is a list 'type' and 'value'. It is always unique and correspond to the primary number
    accession_list = data.pop("accession-list", [])
    data["cellosaurus_id"] = accession_list[0]["value"] if accession_list else None

    # name-list	is a list of 'type' and 'value' (only interested in value). It is always unique.
    name_list = data.pop("name-list", [])
    data["name"] = name_list[0]["value"] if name_list else None

    # child-list is a list of dict with 'accession' and 'name'
    child_list = data.pop("child-list", [])
    data["child_ids"], data["child_names"] = [], []
    for child in child_list:
        acc = child.get("accession", {})
        name = child.get("name", {})
        if acc.get("type", None) == "primary":
            data["child_ids"].append(acc.get("value"))
            data["child_names"].append(name.get("value"))

    # derived-from is a list of dict with 'accession' and 'label' (as name)
    parent_list = data.pop("derived-from", [])
    data["parent_ids"], data["parent_names"] = [], []
    for parent in parent_list:
        data["parent_ids"].append(parent.get("accession"))
        data["parent_names"].append(parent.get("label"))

    # disease-list is a list of dict with 'accession', 'database', 'label' (as name)
    disease_list = data.pop("disease-list", [])
    data["disease_ids"], data["disease_databases"], data["disease_names"] = [], [], []
    for disease in disease_list:
        data["disease_ids"].append(disease.get("accession"))
        data["disease_databases"].append(disease.get("database"))
        data["disease_names"].append(disease.get("label"))

    # xref-list is a list of dict with 'accession', 'database' etc...
    external_ids = data.pop("xref-list", [])
    for database in ["BTO", "EFO", "CLO", "ChEMBL-Cells"]:
        data[f"{database if database != 'ChEMBL-Cells' else 'CHEMBL'}_id"] = [
            x["accession"] for x in external_ids if x["database"] == database
        ]

    # derived-from-site-list is a list of dict with 'value' and many more.
    organ = data.pop("derived-from-site-list", [])
    data["organ"], data["uberon"] = [], []
    for org in organ:
        data["organ"].append(org.get("site", {}).get("value"))
        for ref in org.get("site", {}).get("xref-list", {}):
            if ref.get("database") == "UBERON":
                data["uberon"].append(ref.get("accession"))
                break

    # cell-type is a dict with 'value' and 'xref' which is a dict with accession id, database, database.
    cell_type = data.pop("cell-type", {})
    data.update({key_res: cell_type.get("xref", {}).get(key, None) for key_res, key in zip(
        ["cell_type", "cell_type_id", "cell_type_database"], ["label", "accession", "database"])
    })

    # str-list is a dict with `marker-list` and `source-list`. `marker-list` is a list of dict, containing `id` and
    # `marker-data-list`, a list of a single dict, if no conflict, or multiple
    # containing `marker-alleles`, being a string with the value for that corresponding marker.
    str_dict = data.pop("str-list", {"marker-list": [], "source-list": []})
    str_source_marker = {(
            source.get("xref", {"accession": None}).get("accession") or
            source.get("reference", {"ressource-internal-ref": None}).get("ressource-internal-ref") or
            source.get("institution")
        ): dict() for source in str_dict.get("source-list")
    }
    if str_source_marker:
        for marker in str_dict.get("marker-list"):
            if marker.get("conflict").lower() == "true":
                for allele in marker["marker-data-list"]:
                    for source in allele["source-list"]:
                        if isinstance(source, str):
                            str_source_marker[source].update(
                                {marker["id"]: allele["marker-alleles"]}
                            )

                        else:
                            str_source_marker[(
                                source.get("xref", {"accession": None}).get("accession") or
                                source.get(
                                    "reference", {"ressource-internal-ref": None}
                                ).get("ressource-internal-ref") or
                                source.get("institution")
                            )].update(
                                {marker["id"]: allele["marker-alleles"]}
                            )
            else:
                for source in str_source_marker.keys():
                    str_source_marker[source].update(
                        {marker["id"]: marker["marker-data-list"][0]["marker-alleles"]})
        for str_row in str_source_marker.values():
            str_row.update({"cellosaurus_id": data["cellosaurus_id"]})
            str_rows.append(str_row)
    else:
        str_rows.append({"cellosaurus_id": data["cellosaurus_id"]})


    metadata_rows.append(data)




tahoe_cellosaurus_df = pd.DataFrame(metadata_rows)
tahoe_cellosaurus_df = tahoe_cellosaurus_df.where( # turn None and [] in NaN
    tahoe_cellosaurus_df.map(lambda x: pd.notna(x) if not isinstance(x, list) else len(x) != 0)
).map(lambda x: x if not isinstance(x, list) else (x[0] if len(x) == 1 else x)) # remove empty list

tahoe_str_df = pd.DataFrame(str_rows).drop_duplicates(ignore_index=True)
tahoe_str_df = tahoe_str_df[ # re-order columns to put "cellosaurus_id" first
    ["cellosaurus_id"] + [col for col in tahoe_str_df.columns if col not in ["cellosaurus_id"]]
]
# Out:
# 100%|██████████| 102/102 [00:55<00:00,  1.84it/s]

# %%
tahoe_cellosaurus_df[tahoe_cellosaurus_df["CLO_id"].notna()]
# Out:
#                  age          category     sex cellosaurus_id          name  \
# 0                58Y  Cancer cell line    Male      CVCL_0023         A-549
# 2                65Y  Cancer cell line  Female      CVCL_1282        HMV-II
# 3    Age unspecified  Cancer cell line    Male      CVCL_1034  Hs 936.T(C1)
# 6                69Y  Cancer cell line  Female      CVCL_0031         MCF-7
# 7                67Y  Cancer cell line    Male      CVCL_0039     SK-MEL-30
# ..               ...               ...     ...            ...           ...
# 97               51Y  Cancer cell line    Male      CVCL_1547       NCI-H23
# 98               50Y  Cancer cell line    Male      CVCL_1495     NCI-H1792
# 99               46Y  Cancer cell line  Female      CVCL_1531     NCI-H2122
# 100  Age unspecified  Cancer cell line    Male      CVCL_1517     NCI-H2030
# 101              58Y  Cancer cell line    Male      CVCL_1381      LOX-IMVI
#
# ...

# %% [markdown]
# ### b) STR (Short Tandem Repeat) scoring
# STR profiling is a molecular biology technique used to identify and authenticate cell lines by analyzing specific DNA sequences. It's a powerful tool for ensuring the quality and reliability of cell-based research by detecting misidentified, cross-contaminated, or genetically drifted cell lines.
#
# Inspiration from
# - Cellosaurus [str search tool](https://www.cellosaurus.org/str-search/) and [docs](https://www.cellosaurus.org/str-search/help.html).

# %%
STR_MARKERS = [
    'Amelogenin', 'CSF1PO', 'D2S1338', 'D3S1358',
    'D5S818', 'D7S820', 'D8S1179', 'D13S317',
    'D16S539', 'D18S51', 'D19S433', 'D21S11',
    'FGA', 'Penta D', 'Penta E', 'TH01', 'TPOX', 'vWA',
    'D1S1656', 'D2S441', 'D6S1043',
    'D10S1248', 'D12S391', 'D22S1045',
    'DYS391', 'SE33'
]
STR_MARKERS_CLASTR_DEFAULT = [
    "Amelogenin", "CSF1PO", "D2S1338", "D3S1358",
    "D5S818", "D7S820", "D8S1179", "D13S317",
    "D16S539", "D18S51", "D19S433", "D21S11",
    "FGA", "Penta D", "Penta E", "TH01", "TPOX", "vWA"
]
def str_scoring(
    str_query:pd.Series,
    str_ref:pd.Series,
    scoring_algo: str="tanabe",
    mode: str="non-empty",
    amelogenin: bool=False,
    markers: list[str]=STR_MARKERS_CLASTR_DEFAULT
) -> pd.Series:
    """
    Implement scoring algorithm from CLASTR https://www.cellosaurus.org/str-search/help.html

    Args:
        str_query (pd.Series): The STR marker values for the query cell line.
        str_ref (pd.Series): The STR marker values for the reference cell line.
        scoring_algo (str): The scoring algorithm to use:
            - ``'tanabe'``: Tanabe similarity (recommended).
            - ``'query'``: Shared alleles divided by query alleles.
            - ``'ref'``: Shared alleles divided by reference alleles.

            Formulas:

            - "tanabe":
                .. math::

                    S = \\frac{2N_{shared}}{N_{query} + N_{ref}}

            - "query":
                .. math::

                    S = \\frac{N_{shared}}{N_{query}}

            - "ref":
                .. math::

                    S = \\frac{N_{shared}}{N_{ref}}

            Where:
                - :math:`N_{shared}` is the number of shared alleles across all compared markers.
                - :math:`N_{query}` is the total number of alleles in the query.
                - :math:`N_{ref}` is the total number of alleles in the reference.

        mode (str): Which markers to consider:
            - "non-empty": non NaN markers across query and reference.
            - "query": non NaN markers in query.
            - "ref": non NaN markers in ref.
        amelogenin (bool): Whether to account for the Amelogenin marker or not. Defaults to False.
        markers (list of str): The list of markers to consider. Defaults to STR_MARKERS_CLASTR_DEFAULT

    Returns:
        pd.Series: A single-value Series with the computed score.

    Raises:
        ValueError: If an invalid value is provided for `mode` or `scoring_algo`.
    """
    str_query = str_query[markers]
    str_ref = str_ref[markers]

    if not amelogenin:
        str_query = str_query[[idx for idx in str_query.index if idx not in ["Amelogenin"]]]
        str_ref = str_ref[[idx for idx in str_ref.index if idx not in ["Amelogenin"]]]

    if mode == "non-empty":
        mask = str_query.notna() & str_ref.notna()
    elif mode == "query":
        mask = str_query.notna()
    elif mode == "ref":
        mask = str_ref.notna()
    else:
        raise ValueError("Unexpected `mode` value. Should be one of ['non-empty', 'query', 'ref']")
    str_query = str_query[mask]
    str_ref = str_ref[mask]

    allele_count = (
        pd.concat([str_query.str.split(","), str_ref.str.split(",")], axis=1)
        .apply(
            lambda row:
                pd.Series({
                    "shared": len(set(row.iloc[0]) & set(row.iloc[1])) if pd.notna(row).all() else 0,
                    "query": len(row.iloc[0]) if pd.notna(row).iloc[0] else 0,
                    "ref": len(row.iloc[1]) if pd.notna(row).iloc[1] else 0
                }),
            axis=1
        )
    )

    if scoring_algo == "tanabe":
        score = 2 * allele_count["shared"].sum() / (allele_count[["query", "ref"]].sum().sum())
    elif scoring_algo == "query":
        score = allele_count["shared"].sum() / (allele_count["query"].sum())
    elif scoring_algo == "ref":
        score = allele_count["shared"].sum() / (allele_count["ref"].sum())
    else:
        raise ValueError("Unexpected `scoring_algo` value. Should be one of ['tanabe', 'query', 'ref']")

    return pd.Series({f"score_{scoring_algo}-algo_{mode}-mode_{'with' if amelogenin else 'not'}-amelogenin": score})

# %%
grouped_global, markers_global = None, None
def compute_pairwise_str_score(grouped, id1, id2, markers):
    group1 = grouped.get_group(id1)[markers]
    group2 = grouped.get_group(id2)[markers]

    max_score = 0.0
    for _, row1 in group1.iterrows():
        for _, row2 in group2.iterrows():
            score = str_scoring(
                row1, row2,
                scoring_algo="tanabe",
                mode="non-empty",
                amelogenin=False,
                markers=markers
            ).iloc[0]
            max_score = max(max_score, score)

    return (id1, id2, max_score)

def compute_pairwise_str_initializer(grouped, markers):
    global grouped_global, markers_global
    grouped_global = grouped
    markers_global = markers


def compute_pairwise_str_score_wrapper(idx):
    return compute_pairwise_str_score(grouped_global, *idx, markers_global) # type: ignore

def compute_all_str_scores(
    tahoe_str_df: pd.DataFrame,
    markers: list[str],
    n_threads: int=8
) -> pd.DataFrame:

    # Group rows by cellosaurus_id
    grouped = tahoe_str_df.groupby("cellosaurus_id")
    ids = sorted(grouped.groups.keys()) # type: ignore

    # Init square score matrix
    score_matrix = pd.DataFrame(index=ids, columns=ids, dtype=float)

    pairs = list(combinations(ids, 2))
    with Pool(processes=n_threads, initializer=compute_pairwise_str_initializer, initargs=(grouped, markers,)) as pool:
        results = list(
            tqdm(pool.imap_unordered(compute_pairwise_str_score_wrapper, pairs),
                total=len(pairs), desc="Computing STR scores")
        )

    for id1, id2, score in results:
        score_matrix.loc[id1, id2] = score
        score_matrix.loc[id2, id1] = score

    for id in ids:
        score_matrix.loc[id, id] = 1.0

    return score_matrix

# %%
score_df = compute_all_str_scores(
    tahoe_str_df,
    markers=STR_MARKERS_CLASTR_DEFAULT,
    n_threads=16
)
# Out:
# Computing STR scores: 100%|██████████| 5151/5151 [00:28<00:00, 178.57it/s]

# %% [markdown]
# ### c) Clustermap of cell lines

# %%
score_matrix_clipped = score_df.clip(lower=0, upper=1)
id_to_name = tahoe_cellosaurus_df.set_index("cellosaurus_id")["name"].to_dict()
score_df_named = score_matrix_clipped.rename(index=id_to_name, columns=id_to_name)

# Metadata to annotate
metadata = ["organ"]

# Align metadata
metadata_df = (
    tahoe_cellosaurus_df
    .set_index("name")
    .loc[score_df_named.index][metadata]
    .fillna("nan")
    .astype(str)
)


# Build color palettes and row_colors (same as before)
metadata_palette_dict = {
    met: sns.color_palette("Spectral", metadata_df[met].nunique()) #Set{i+1}
    for i, met in enumerate(metadata)
}
metadata_colors_dict = {
    met: dict(zip(metadata_df[met].dropna().unique(), metadata_palette_dict[met]))
    for met in metadata
}
row_colors = pd.DataFrame({
    met.capitalize(): metadata_df[met].map(metadata_colors_dict[met])
    for met in metadata
})

# Create clustermap
g = sns.clustermap(
    score_df_named,
    cmap="viridis",
    figsize=(12, 12),
    row_cluster=True,
    col_cluster=True,
    dendrogram_ratio=(0.1, 0.1),
    cbar_pos=(0.95, 0.8, 0.03, 0.18),
    xticklabels=True,
    yticklabels=True,
    row_colors=row_colors,
    col_colors=row_colors,
)

# Resize tick labels
g.ax_heatmap.set_xticklabels(g.ax_heatmap.get_xticklabels(), fontsize=8)
g.ax_heatmap.set_yticklabels(g.ax_heatmap.get_yticklabels(), fontsize=8)

# Create external legend axes (new)
legend_ax = g.figure.add_axes((0.91, 0.3, 0.08, 0.4))  # [left, bottom, width, height]
legend_ax.axis("off")

# Collect all legend handles from both metadata fields
all_handles = []
for met in metadata:
    handles = [
        mpatches.Patch(color=to_hex(col), label=f"{met.capitalize()}: {label}")
        for label, col in metadata_colors_dict[met].items()
    ]
    all_handles.extend(handles)

# Add combined legend
legend_ax.legend(handles=all_handles, loc="center left", fontsize=8, title="Metadata", title_fontsize=9)

# Add title
plt.suptitle("STR Similarity Clustermap", y=1.02, fontsize=14)
plt.show()

# %% [markdown]
# ### d) Organ (UBERON) ontology

# %%
request.urlretrieve(# do not pay attention to number -8 link. They mismatch the order. This correspond to TableS1.
    url="https://purl.obolibrary.org/obo/uberon.owl",
    filename=data_path.joinpath("ontology/uberon.owl")
)
uberon = Ontology(
    data_path.joinpath("ontology/uberon.owl")
)
uberon_tahoe_ids = set(list(tahoe_cellosaurus_df["uberon"].dropna().str.replace("_", ":").unique()))
# Out:
# /home/hhakem/projects/cellarium-ml/.venv/lib/python3.11/site-packages/pronto/parsers/rdfxml.py:114: SyntaxWarning: unknown element in `owl:ObjectProperty`: <Element '{http://purl.obolibrary.org/obo/}IAO_0000112' at 0x779a6e55bb00>
#   self._extract_object_property(prop, curies)
# /home/hhakem/projects/cellarium-ml/.venv/lib/python3.11/site-packages/pronto/parsers/rdfxml.py:114: SyntaxWarning: unknown element in `owl:ObjectProperty`: <Element '{http://purl.obolibrary.org/obo/}IAO_0000112' at 0x779a6e55bb50>
#   self._extract_object_property(prop, curies)
# /home/hhakem/projects/cellarium-ml/.venv/lib/python3.11/site-packages/pronto/parsers/rdfxml.py:114: SyntaxWarning: unknown element in `owl:ObjectProperty`: <Element '{http://purl.obolibrary.org/obo/}IAO_0000112' at 0x779a6e55bba0>
#   self._extract_object_property(prop, curies)
# ...

# %%
def compute_paths_for_pair(G: nx.DiGraph, G_reversed: nx.DiGraph, pairs: tuple[str, str], lowest_ancestor: str) -> set[str]:
    if pairs[0] not in G or pairs[1] not in G:
        return set()
    lengths = tuple(nx.shortest_path_length(G=G, source=lowest_ancestor, target=id) for id in pairs)
    lowest_common_ancestors = set.intersection(
        *[set(dict(nx.bfs_predecessors(G_reversed, source=id, depth_limit=max(lengths))).keys()) for id in pairs]
    )
    lcas = lowest_common_ancestors.copy()
    for a in lowest_common_ancestors:
        for b in lowest_common_ancestors:
            if a != b and nx.has_path(G, a, b):
                lcas.discard(a)
                break
    included = set()
    for lca in lcas:
        for target in pairs:
            try:
                for path in nx.all_simple_paths(G, lca, target):
                    included.update(path)
            except nx.NetworkXNoPath:
                pass
    return included

G_global = None
G_reversed = None

def compute_path_initializer(G, G_reversed):
    global G_global, G_global_reversed
    G_global = G
    G_global_reversed = G_reversed


def compute_paths_wrapper(pairs_ancestor):
    return compute_paths_for_pair(G_global, G_global_reversed, *pairs_ancestor) # type: ignore

def get_lca_subgraph_parallel(G: nx.DiGraph, ids: set[str], n_threads: int = 4) -> nx.DiGraph:
    pairs = list(combinations(ids, 2))
    # lowest common ancestor return the single lowest common ancestor. If there is multiple,
    # take one randomly. By knowing it, one can know the shortest depth of the common ancestor,
    # From there, it suffice, 
    pairs_ancestor_iterator = list(nx.all_pairs_lowest_common_ancestor(G, pairs=pairs))
    G_reversed = nx.reverse(G)
    with Pool(processes=n_threads, initializer=compute_path_initializer, initargs=(G, G_reversed)) as pool:
        results = list(
            tqdm(pool.imap_unordered(
                compute_paths_wrapper,
                pairs_ancestor_iterator), total=len(pairs_ancestor_iterator), desc="Computing sub graph")
        )

    included_nodes = set(ids)
    for nodes in results:
        included_nodes.update(nodes)

    return G.subgraph(included_nodes).copy()

# %%
G = nx.DiGraph()
for term in uberon.terms():
    G.add_node(term.id, label=term.name)
    for parent in term.superclasses(with_self=False, distance=1):
        G.add_edge(parent.id, term.id)


subG = get_lca_subgraph_parallel(G, uberon_tahoe_ids, n_threads=16)
# Out:
# Computing sub graph: 100%|██████████| 276/276 [00:07<00:00, 34.98it/s]

# %%
# 1. Compute Louvain clusters
undirected = subG.to_undirected()
partition = community_louvain.best_partition(undirected, random_state=42)
num_clusters = len(set(partition.values()))
cmap = cm.get_cmap("tab20", num_clusters)
node_colors = [cmap(partition[n]) for n in subG.nodes]

# 2. Use Graphviz layout (DAG-aware)
def trim_uberon(id:str) -> str: return id.replace("UBERON:", "") # need to rename because of weird paring in pydot
G_safe = nx.relabel_nodes(subG, trim_uberon) # type: ignore
pos = nx.drawing.nx_pydot.graphviz_layout(G_safe, prog="sfdp")  # top-down DAG layout
trim_uberon_tahoe_ids = {trim_uberon(id) for id in uberon_tahoe_ids}

# 3. Draw with node coloring + alpha
plt.figure(figsize=(20, 10))
# Alpha
nodes_alpha = [1.0 if n in trim_uberon_tahoe_ids else 0.1 for n in G_safe.nodes]
edges_alpha = [1.0 if {src, dst} < trim_uberon_tahoe_ids else 0.1 for (src, dst) in G_safe.edges]

nx.draw_networkx_nodes(
    G_safe,
    pos,
    node_color=node_colors, # type: ignore
    node_size=180,
    alpha=nodes_alpha,
    linewidths=0.5,
    edgecolors="black"
)

nx.draw_networkx_edges(
    G_safe,
    pos,
    arrows=True,
    arrowstyle="-|>",
    arrowsize=12,
    edge_color="gray",
    alpha=edges_alpha,
    width=1.2
)

nx.draw_networkx_labels(
    G_safe,
    pos,
    labels=nx.get_node_attributes(G_safe, "label"),
    font_size=6
)
# Add legend
handles = [
    Patch(color=cmap(cluster_id), label=f"Cluster {cluster_id}")
    for cluster_id in sorted(set(partition.values()))
]
plt.legend(handles=handles, title="Louvain Clusters", loc="center left", bbox_to_anchor=(1, 0.5))
plt.title("Uberon Subgraph with Graphviz Layout + Louvain Clustering")
plt.axis("off")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_830107/426637796.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap("tab20", num_clusters)

# %% [markdown]
# ### e) Disease (NCIT) ontology

# %%
request.urlretrieve(# do not pay attention to number -8 link. They mismatch the order. This correspond to TableS1.
    url="https://purl.obolibrary.org/obo/ncit.owl",
    filename=data_path.joinpath("ontology/ncit.owl")
)
ncit = Ontology(
    data_path.joinpath("ontology/ncit.owl")
)
ncit_tahoe_ids = set(list(
    tahoe_cellosaurus_df[["disease_ids", "disease_databases"]]
    .apply(
        lambda row:
            row.apply(lambda x: x if isinstance(x, list) else [x]),
        axis=1)
    .apply(
        lambda row:
            [id for id, db in list(zip(*row.values)) if db == "NCIt"],
        axis=1)
    .explode()
    .dropna()
    .apply(lambda row: "NCIT:" + row)
    .unique()
))
# Out:
# /home/hhakem/projects/cellarium-ml/.venv/lib/python3.11/site-packages/pronto/ontology.py:290: NotImplementedWarning: cannot process plain `owl:AnnotationProperty`
#   cls(self).parse_from(_handle)  # type: ignore
# /home/hhakem/projects/cellarium-ml/.venv/lib/python3.11/site-packages/pronto/parsers/rdfxml.py:118: SyntaxWarning: unknown element in `owl:Class`: {http://www.w3.org/2002/07/owl#}equivalentClass
#   self._extract_term(class_, curies)
# /home/hhakem/projects/cellarium-ml/.venv/lib/python3.11/site-packages/pronto/parsers/rdfxml.py:118: SyntaxWarning: cannot process `rdfs:subClassOf` in this context
#   self._extract_term(class_, curies)
# /home/hhakem/projects/cellarium-ml/.venv/lib/python3.11/site-packages/pronto/parsers/rdfxml.py:118: SyntaxWarning: unknown element in `owl:Class`: {http://purl.obolibrary.org/obo/}NCIT_P107
#   self._extract_term(class_, curies)
# ...

# %%
G = nx.DiGraph()
for term in ncit.terms():
    G.add_node(term.id, label=term.name)
    for parent in term.superclasses(with_self=False, distance=1):
        G.add_edge(parent.id, term.id)

subG = get_lca_subgraph_parallel(G, ncit_tahoe_ids, n_threads=16)
# Out:
# Computing sub graph: 100%|██████████| 820/820 [05:54<00:00,  2.31it/s]

# %%
# 1. Compute Louvain clusters
undirected = subG.to_undirected()
partition = community_louvain.best_partition(undirected, random_state=42)
num_clusters = len(set(partition.values()))
cmap = cm.get_cmap("tab20", num_clusters)
node_colors = [cmap(partition[n]) for n in subG.nodes]

# 2. Use Graphviz layout (DAG-aware)
def trim_ncit(id:str) -> str: return id.replace("NCIT:", "") # need to rename because of weird paring in pydot
G_safe = nx.relabel_nodes(subG, trim_ncit) # type: ignore
pos = nx.drawing.nx_pydot.graphviz_layout(G_safe, prog="sfdp")  # top-down DAG layout
trim_ncit_tahoe_ids = {trim_ncit(id) for id in ncit_tahoe_ids}

# 3. Draw with node coloring + alpha
plt.figure(figsize=(20, 10))

# Alpha
nodes_alpha = [1.0 if n in trim_ncit_tahoe_ids else 0.1 for n in G_safe.nodes]
edges_alpha = [1.0 if {src, dst} < trim_ncit_tahoe_ids else 0.1 for (src, dst) in G_safe.edges]

nx.draw_networkx_nodes(
    G_safe,
    pos,
    node_color=node_colors,  # type: ignore
    node_size=180,
    alpha=nodes_alpha,
    linewidths=0.5,
    edgecolors="black"
)

nx.draw_networkx_edges(
    G_safe,
    pos,
    arrows=True,
    arrowstyle="-|>",
    arrowsize=12,
    edge_color="gray",
    alpha=edges_alpha,
    width=1.2
)

nx.draw_networkx_labels(
    G_safe,
    pos,
    labels=nx.get_node_attributes(G_safe, "label"),
    font_size=6
)

# Add legend
handles = [
    Patch(color=cmap(cluster_id), label=f"Cluster {cluster_id}")
    for cluster_id in sorted(set(partition.values()))
]
plt.legend(handles=handles, title="Louvain Clusters", loc="center left", bbox_to_anchor=(1, 0.5))
plt.title("NCIT Subgraph with Graphviz Layout + Louvain Clustering")
plt.axis("off")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_830107/1650492824.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap("tab20", num_clusters)

# %% [markdown]
# ### f) CLO Ontology

# %%
request.urlretrieve(# do not pay attention to number -8 link. They mismatch the order. This correspond to TableS1.
    url="https://purl.obolibrary.org/obo/clo.owl",
    filename=data_path.joinpath("ontology/clo.owl")
)
clo = Ontology(
    data_path.joinpath("ontology/clo.owl")
)
clo_tahoe_ids = set(list(
    tahoe_cellosaurus_df["CLO_id"]
    .explode()
    .dropna()
    .str.replace("_", ":")
    .unique()
))
# Out:
# /tmp/ipykernel_830107/1105019675.py:5: UnicodeWarning: unsound encoding, assuming MacRoman (73% confidence)
#   clo = Ontology(
# /home/hhakem/projects/cellarium-ml/.venv/lib/python3.11/site-packages/pronto/parsers/rdfxml.py:114: SyntaxWarning: unknown element in `owl:ObjectProperty`: <Element '{http://purl.obolibrary.org/obo/}IAO_0000111' at 0x7798e6f883b0>
#   self._extract_object_property(prop, curies)
# /home/hhakem/projects/cellarium-ml/.venv/lib/python3.11/site-packages/pronto/parsers/rdfxml.py:114: SyntaxWarning: unknown element in `owl:ObjectProperty`: <Element '{http://purl.obolibrary.org/obo/}IAO_0000112' at 0x7798e6f88630>
#   self._extract_object_property(prop, curies)
# /home/hhakem/projects/cellarium-ml/.venv/lib/python3.11/site-packages/pronto/parsers/rdfxml.py:114: SyntaxWarning: unknown element in `owl:ObjectProperty`: <Element '{http://purl.obolibrary.org/obo/}IAO_0000112' at 0x7798e6f88e50>
#   self._extract_object_property(prop, curies)
# ...

# %%
G = nx.DiGraph()
for term in clo.terms():
    G.add_node(term.id, label=term.name)
    for parent in term.superclasses(with_self=False, distance=1):
        G.add_edge(parent.id, term.id)

subG = get_lca_subgraph_parallel(G, clo_tahoe_ids, n_threads=16)
# Out:
# Computing sub graph:  71%|███████   | 6116/8646 [11:26<04:44,  8.90it/s]Process ForkPoolWorker-68:
# Process ForkPoolWorker-75:
# Process ForkPoolWorker-74:
# Process ForkPoolWorker-65:
# Process ForkPoolWorker-67:
# Process ForkPoolWorker-70:
# Process ForkPoolWorker-73:
# Process ForkPoolWorker-76:
# Process ForkPoolWorker-69:
# Process ForkPoolWorker-77:
# Process ForkPoolWorker-72:
# Process ForkPoolWorker-71:
# Process ForkPoolWorker-79:
# Process ForkPoolWorker-80:
# Process ForkPoolWorker-66:
# Process ForkPoolWorker-78:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# ...

# %% [markdown]
# ## 3) Cellosaurus Ontology

# %%
request.urlretrieve(# do not pay attention to number -8 link. They mismatch the order. This correspond to TableS1.
    url="https://ftp.expasy.org/databases/cellosaurus/cellosaurus.obo",
    filename=data_path.joinpath("ontology/cellosaurus.obo")
)
# Out:
# (PosixPath('../../datasets/ontology/cellosaurus.obo'),
#  <http.client.HTTPMessage at 0x792a24295090>)

# %%
def sanitize_obo(input_path, output_path):
    with open(input_path, "r", encoding="utf-8") as infile, open(output_path, "w", encoding="utf-8") as outfile:
        for line in infile:
            stripped = line.strip()

            # Skip comment-only lines
            if stripped.startswith("!"):
                continue

            # Fix unquoted xref values with spaces
            if stripped.startswith("xref:"):
                # Example: xref: IZSLER:BS CL 93
                # Proper format: xref: "IZSLER:BS CL 93"
                parts = line.split("xref:", maxsplit=1)
                rest = parts[1].strip()

                # If rest has spaces and is not quoted, quote it
                if " " in rest and not rest.startswith('"'):
                    if "!" in rest:
                        parts = rest.split("!", maxsplit=1)
                        core, comment = parts[0].strip(), parts[1].strip()
                        core = core.replace(" ", "_")
                        rest = f'{core} ! {comment}'
                    else:
                        rest = rest.replace(" ", "_")

                line = f"xref: {rest}\n"

            outfile.write(line)

sanitize_obo(data_path.joinpath("ontology/cellosaurus.obo"), data_path.joinpath("ontology/cellosaurus_cleaned.obo"))

# %%
cvcl = Ontology(
    data_path.joinpath("ontology/cellosaurus_cleaned.obo")
)

# %%
sex_subsets = {"Female", "Male", "Mixed_sex", "Sex_ambiguous", "Sex_unspecified"}
G = nx.DiGraph()
def unpack_set(s: set[str]) -> str: return list(s)[0] if len(s) == 1 else ", ".join(list(s))
for term in cvcl.terms():
    sex = unpack_set(set(term.subsets) & sex_subsets or {"None_sex"})
    cell_line_type = unpack_set(set(term.subsets) - sex_subsets or {"Undefined_cell_line_type"})
    G.add_node(term.id, label=term.name, sex=sex, cell_line_type=cell_line_type)
    for rel_type, rel_terms in term.relationships.items():
        for term2 in rel_terms:
            if rel_type.id == "originate_from_same_individual_as":
                G.add_edge(term.id, term2.id, relation=rel_type.id)
                G.add_edge(term2.id, term.id, relation=rel_type.id)
            if rel_type.id == "derived_from":
                G.add_edge(term2.id, term.id, relation=rel_type.id)

# %%
tahoe_ids = set(cellosaurus_ids)
subG = get_lca_subgraph_parallel(G, tahoe_ids)
# Out:
# Computing sub graph: 100%|██████████| 5151/5151 [00:00<00:00, 6141.77it/s]

# %%
pos = nx.drawing.nx_pydot.graphviz_layout(subG, prog="sfdp")

# === SECTION: Node colors ===
sexes = sorted(list({data["sex"] for _, data in subG.nodes(data=True)}))
cell_types = sorted(list({data["cell_line_type"] for _, data in subG.nodes(data=True)}))

sex_colors = dict(zip(sexes, plt.cm.tab10.colors[len(cell_types):len(cell_types) + len(sexes)])) # type: ignore
cell_type_colors = dict(zip(cell_types, plt.cm.tab10.colors[:len(cell_types)])) # type: ignore

outer_colors = [sex_colors[subG.nodes[n]["sex"]] for n in subG.nodes]
inner_colors = [cell_type_colors[subG.nodes[n]["cell_line_type"]] for n in subG.nodes]

# === SECTION: Node alphas ===
node_alphas = [1.0 if n in tahoe_ids else 0.2 for n in subG.nodes]

# === SECTION: Edge color ===
# --- Edge colors based on relation ---
edge_colors = []
edge_alphas = []
for u, v, data in subG.edges(data=True):
    if data.get("relation") == "derived_from":
        edge_colors.append("blue")
    elif data.get("relation") == "originate_from_same_individual_as":
        edge_colors.append("red")
    else:
        edge_colors.append("lightgray")  # fallback color
    if u not in tahoe_ids or v not in tahoe_ids:
        edge_alphas.append(0.2)
    else:
        edge_alphas.append(1)

plt.figure(figsize=(12, 9))

# Draw outer ring (sex)
nx.draw_networkx_nodes(
    subG,
    pos,
    node_size=400,
    node_color=outer_colors, # type: ignore
    linewidths=0,
    edgecolors='black',
    alpha=node_alphas
)

# Draw inner dot (cell line type)
nx.draw_networkx_nodes(
    subG,
    pos,
    node_size=150,
    node_color=inner_colors, # type: ignore
    alpha=node_alphas
)

nx.draw_networkx_labels(subG, pos, labels=nx.get_node_attributes(subG, "label"), font_size=6)
nx.draw_networkx_edges(
    subG,
    pos,
    arrows=True,
    arrowsize=20,
    edge_color=edge_colors, # type: ignore
    alpha=edge_alphas,
    width=1.2
)

plt.axis('off')

# === SECTION: Legend ===


sex_patches = [mpatches.Patch(color=color, label=sex) for sex, color in sex_colors.items()]
cell_type_patches = [mpatches.Patch(color=color, label=ctype) for ctype, color in cell_type_colors.items()]
edge_patches = [
    mpatches.Patch(color="blue", label="derived_from"),
    mpatches.Patch(color="red", label="originate_from_same_individual_as")
]

# Add legends
leg1 = plt.legend(handles=sex_patches, title="Sex (outer ring)", loc='upper left', bbox_to_anchor=(1, 1))
leg2 = plt.legend(handles=cell_type_patches, title="Cell Line Type (inner dot)", loc='upper left', bbox_to_anchor=(1, 0.7))
leg3 = plt.legend(handles=edge_patches, title="Relationship (edge color)", loc='upper left', bbox_to_anchor=(1, 0.55))

# Add the first legend back manually to the plot
plt.gca().add_artist(leg1)
plt.gca().add_artist(leg2)

plt.show()
